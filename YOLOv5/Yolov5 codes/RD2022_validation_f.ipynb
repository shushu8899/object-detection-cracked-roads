# %%
# %run detect.py --weights best.pt --source ../RDD2022/test/images
# Out:
# detect: weights=['best.pt'], source=../RDD2022/test/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-321-g3742ab49 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2012 C:\Users\shuji\OneDrive\Desktop\School\CS610\RDD2022\test\images\China_MotorBike_000004.jpg: 640x640 1 D40, 1 Repair, 1898.7ms
# image 2/2012 C:\Users\shuji\OneDrive\Desktop\School\CS610\RDD2022\test\images\China_MotorBike_000018.jpg: 640x640 1 D10, 4927.8ms
# ...

# %%
# %run detect.py --weights best.pt --data RDD2022_dataset.yaml --source ../RDD2022/validation/images --iou 0.8
# Out:
# detect: weights=['best.pt'], source=../RDD2022/validation/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.8, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-321-g3742ab49 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4024 C:\Users\shuji\OneDrive\Desktop\School\CS610\RDD2022\validation\images\China_MotorBike_000006.jpg: 640x640 2 D00s, 2 D10s, 421.0ms
# image 2/4024 C:\Users\shuji\OneDrive\Desktop\School\CS610\RDD2022\validation\images\China_MotorBike_000008.jpg: 640x640 (no detections), 314.8ms
# ...

# %% [markdown]
# YOLOv5S

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml  --iou-thres 0.8
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.8, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2024-6-16 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning C:\Users\shuji\OneDrive\Desktop\School\CS610\Model for yolov5\RDD2022\validation\labels... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:46<00:00, 86.02it/s]
# ...

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml --iou-thres 0.6
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-321-g3742ab49 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning C:\Users\shuji\OneDrive\Desktop\School\CS610\RDD2022\validation\labels.cache... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 126/126 [37:59<00:00, 18.09s/it]
#                    all       4024       8398      0.622      0.583      0.608      0.303
# ...

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml --iou-thres 0.5
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-321-g3742ab49 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning C:\Users\shuji\OneDrive\Desktop\School\CS610\RDD2022\validation\labels.cache... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 126/126 [42:11<00:00, 20.09s/it]
#                    all       4024       8398      0.618      0.595      0.616      0.301
# ...

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml  --iou-thres 0.8
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.8, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-321-g3742ab49 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning C:\Users\shuji\OneDrive\Desktop\School\CS610\RDD2022\validation\labels.cache... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\OneDrive\Desktop\School\CS610\yolov5\val.py:438
#     436 if __name__ == "__main__":
#     437     opt = parse_opt()
# --> 438     main(opt)
#
# ...

# %% [markdown]
# Yolov5M Validation

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml  --iou-thres 0.8
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.8, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2024-6-17 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20889303 parameters, 0 gradients, 48.0 GFLOPs
# val: Scanning C:\Users\lowju\SJ's files\CS610\RDD2022\validation\labels.cache... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 126/126 [29:36<00:00, 14.10s/it]
#                    all       4024       8398      0.538       0.59      0.552      0.316
#                    D00       4024       2866      0.528      0.555      0.535      0.284
# ...

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml --iou-thres 0.6
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2024-6-17 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20889303 parameters, 0 gradients, 48.0 GFLOPs
# val: Scanning C:\Users\lowju\SJ's files\CS610\RDD2022\validation\labels.cache... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 126/126 [29:45<00:00, 14.17s/it]
#                    all       4024       8398      0.663      0.647      0.669      0.366
#                    D00       4024       2866      0.604      0.622       0.63      0.314
# ...

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml --iou-thres 0.5
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2024-6-17 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20889303 parameters, 0 gradients, 48.0 GFLOPs
# val: Scanning C:\Users\lowju\SJ's files\CS610\RDD2022\validation\labels.cache... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 126/126 [29:22<00:00, 13.99s/it]
#                    all       4024       8398      0.672      0.653      0.673      0.364
#                    D00       4024       2866      0.603       0.63      0.634      0.311
# ...

# %%
# %run val.py --weights best.pt --data RDD2022_dataset.yaml --iou-thres 0.4
# Out:
# val: data=RDD2022_dataset.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.4, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2024-6-17 Python-3.9.19 torch-2.3.1+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20889303 parameters, 0 gradients, 48.0 GFLOPs
# val: Scanning C:\Users\lowju\SJ's files\CS610\RDD2022\validation\labels.cache... 4024 images, 527 backgrounds, 0 corrupt: 100%|██████████| 4024/4024 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 126/126 [28:40<00:00, 13.65s/it]
#                    all       4024       8398       0.68      0.652       0.67       0.36
#                    D00       4024       2866      0.606      0.628       0.63      0.307
# ...
